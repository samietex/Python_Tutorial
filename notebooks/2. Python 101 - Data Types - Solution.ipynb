# %% [markdown]
# # 1. BOOLEANS

# %%
Uzi = 5
David = 5

# Comparison operators

# == is equal to
# > is greater than
# < is less than
# >= is greater or equal to
# <= is less than or equal to
# != is not equal to
# Out:
# True

# %%
# Boolean values can be represented as one of two constant objects "False" and "True".
# Booleans behave like integers 0 and 1.
x == 2
# Out:
# True

# %%
False
# Out:
# False

# %%
x = 20
y = 10

x != y
# Out:
# True

# %%
stock_1_price = 20000
stock_2_price = 20000

print((stock_1_price != stock_2_price) or (stock_1_price == stock_2_price)) # the != sign means not equal to
# Out:
# True

# %%
False or True
# Out:
# True

# %%
# AND Operator
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
# OR Operator
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **What will this code generate?**
# ```
# stock_1_price = 20
# stock_2_price = 30
# print((stock_1_price < stock_2_price))
# print(stock_1_price == stock_2_price)
# ```

# %%
stock_1_price = 20
stock_2_price = 30
print((stock_1_price < stock_2_price))
print(stock_1_price == stock_2_price) # The == sign means equal to for comparison
# Out:
# True
# False

# %%
'Gomycode' == 'gomycode'
# Out:
# False

# %% [markdown]
# # 2. LIST

# %%
# A list is a collection which is ordered and changeable.
# List allows duplicate members.
datascience = [20]
datascience
# Out:
# [20]

# %%
# Obtain the datatype
type(datascience)
# Out:
# list

# %%
# list with mixed datatypes (for example you can have strings and integers in one list)
school = ['Gomycode', 'Datascience', 'Nigeria', 10, 20, 30, 'Joshua', 'Olatunde']
school
# Out:
# ['Gomycode', 'Datascience', 'Nigeria', 10, 20, 30, 'Joshua', 'Olatunde']

# %%
type(school)
# Out:
# list

# %%
cls = 'Data Science'

# %%
cls[-8]
# Out:
# ' '

# %%
denis[1:4]
# Out:
# [30, 40, ['Olamide', 'Joshua', 'David', 20], 30, 'Oladimeji']

# %%
denis[3][2]
# Out:
# 'David'

# %%
# You can have a list inside another list (nested list)
denis = [20, 30, 40, ['Olamide', 'Joshua', 'David', 20], 30, 'Oladimeji']
denis
# Out:
# [20, 30, 40, ['Olamide', 'Joshua', 'David', 20], 30, 'Oladimeji']

# %%
denis[0]
# Out:
# 'Olakunle'

# %%
denis[1] = [23, 4, 'Class']

# %%
denis
# Out:
# [20, [23, 4, 'Class'], 40, ['Olamide', 'Joshua', 'David', 20], 30, 'Oladimeji']

# %%
# Out:
# 800

# %%
denis[-3]
# Out:
# ['Olamide', 'Joshua', 'David', 20]

# %%
denis[2:]
# Out:
# ['Senior man', [20, 'Gomycode'], 30, 40]

# %%
type(denis)
# Out:
# list

# %%
denis[3]
# Out:
# [20, 'Gomycode']

# %%
denis[3][0]
# Out:
# 20

# %%
type(jide)
# Out:
# list

# %%
jide[3] = [3, 5, 'Gomycode', 'Datascience', 'Mr Prince', 'Outsider', 'Islander']
jide[3]
# Out:
# [10,
#  2,
#  'Lagos',
#  [3, 5, 'Gomycode', 'Datascience', 'Mr Prince', 'Outsider', 'Islander'],
#  45,
#  'Ebele']

# %%
jide
# Out:
# [10,
#  2,
#  'Lagos',
#  [3, 5, 'Gomycode', 'Datascience', 'Mr Prince', 'Outsider', 'Islander'],
#  45,
#  'Ebele']

# %%
x = [70, 80, 90, 100, 200, 'SDC', 'Election', 40, 23, 55, 98]
x

# To print the 1 position element to the very end:

x[-7:]
# Out:
# [200, 'SDC', 'Election', 40, 23, 55, 98]

# %%
jide[-3]
# Out:
# [3, 5, 'Gomycode', 'Datascience', 'Mr Prince', 'Outsider', 'Islander']

# %%
print(jide[3][6])
# Out:
# Islander

# %%
# Access specific elements in the list with Indexing
# Note that the first element in the list has an index of 0 (little confusing but you'll get used to it!)
my_list = [2, "GOOG", 5]
my_list[1]
# Out:
# 'GOOG'

# %%
# indexing for nested lists
my_list = ["GOOG", [3, 6, 7], ["APPL", 5, 6]]
my_list[2][0]
# Out:
# 'APPL'

# %%
print(my_list[1][1])
# Out:
# 6

# %%
print(my_list[2])
# Out:
# ['APPL', 5, 6]

# %%
# Negative Indexing
my_list = [2, "GOOG", 5]
print(my_list[-2])
# Out:
# GOOG

# %%
# List Slicing (getting more than one element from a list)
my_list = [2, 5, 7, "GOOG", "SP500", "AMZN", 15]

# obtain elements starting from index 3 up to and not including element with index 6
print(my_list[3:6])
# Out:
# ['GOOG', 'SP500', 'AMZN']

# %%
my_list[0], my_list[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-fe4966a18b1e> in <cell line: 1>()
# ----> 1 my_list[0:2,3]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
# Obtain elements starting from index 3 to end
print(my_list[3:])
# Out:
# ['GOOG', 'SP500', 'AMZN', 15]

# %%
# All elements start to end
print(my_list[:])
# Out:
# [2, 5, 7, 'GOOG', 'SP500', 'AMZN', 15]

# %%
# Obtain the length of the list (how many elements in the list)
len(my_list)
# Out:
# 7

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Print the first, second and last element in the list below**
# - **Print all elements in the list, first 3 elements, and last three elements**
#
# ```
# stocks = ["GOOG", "TSLA", "AAPL", "T", "SP500", "BTC", "EUR/USD"]
# ```

# %%
stocks = ["GOOG", "TSLA", "AAPL", "T", "SP500", "BTC", "EUR/USD"]

# %%
print(stocks[0],stocks[1],stocks[6])
# Out:
# GOOG TSLA EUR/USD

# %%
x = stocks[0:3]
y = stocks[-3:]

x+y
# Out:
# ['GOOG', 'TSLA', 'AAPL', 'SP500', 'BTC', 'EUR/USD']

# %%
print(stocks[0:3],stocks[-3:])
# Out:
# ['GOOG', 'TSLA', 'AAPL'] ['SP500', 'BTC', 'EUR/USD']

# %%
print(stocks[-3:])
# Out:
# ['SP500', 'BTC', 'EUR/USD']

# %%
print(stocks[0],stocks[1],stocks[6])
# Out:
# GOOG TSLA EUR/USD

# %%
print(stocks)
# Out:
# ['GOOG', 'TSLA', 'AAPL', 'T', 'SP500', 'BTC', 'EUR/USD']

# %%
stocks[0:3],stocks[4:7]
# Out:
# (['GOOG', 'TSLA', 'AAPL'], ['SP500', 'BTC', 'EUR/USD'])

# %%
print(stocks[0],stocks[1],stocks[6])
# Out:
# GOOG TSLA EUR/USD

# %%
print(stocks)
# Out:
# ['GOOG', 'TSLA', 'AAPL', 'T', 'SP500', 'BTC', 'EUR/USD']

# %%
print(stocks[0:3],stocks[4:7])
# Out:
# ['GOOG', 'TSLA', 'AAPL'] ['SP500', 'BTC', 'EUR/USD']

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Print GOOG**
# - **Print AAPL, GOOG, TSLA**
# - **Print T with two different ways**
#
# ```
# my_list = ["SP500", ["AAPL", "GOOG", "TSLA"], "BTC", "T"]
# ```

# %%
my_list[3]
# Out:
# 'T'

# %%
my_list = ["SP500", ["AAPL", "GOOG", "TSLA"], "BTC", "T"]

# %%
my_list[2][1]
# Out:
# 'T'

# %%
print(my_list[1][2])
# Out:
# AAPL

# %%
print(my_list[1])
# Out:
# ['AAPL', 'GOOG', 'TSLA']

# %%
my_list[3]
# Out:
# 'T'

# %%
my_list[-1]
# Out:
# 'T'

# %%
# To print AAPL, GOOG, TSLA

print(my_list[1])
# Out:
# ['AAPL', 'GOOG', 'TSLA']

# %%
my_list[-1]
# Out:
# 'T'

# %% [markdown]
# # 3. DICTIONARY

# %%
# my_dict = {'key1':'value1', 'key2':'value2', 'key3':'value3'}
# Dictionary consists of a collection of key-value pairs. Each key-value pair maps the key to its corresponding value.
# Keys are unique within a dictionary while values may not be.
# List elements are accessed by their position in the list, via indexing while Dictionary elements are accessed via keys

# Define a dictionary using key-value pairs
students = {'name' : 'Oladimeji', 'age' : 30, 'school' : 'Gomycode', 'names' : 'David'}
students
# Out:
# {'name': 'Oladimeji', 'age': 30, 'school': 'Gomycode', 'names': 'David'}

# %%
students['Weight'] = '75 kg'

# %%
students['Race'] = 'Black'

# %%
students['age'] =

# %%
del students

# %%
students
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-f5ca085dbaa1> in <cell line: 1>()
# ----> 1 students
#
# NameError: name 'students' is not defined

# %%
del students['Oladimeji']

# %%
students['Oladimeji'] = 'namessss'

# %%
students['Height'] = '184 cm'

# %%
students.items()
# Out:
# dict_items([('name', 'Oladimeji'), ('age', 30), ('school', 'Gomycode'), ('names', 'David')])

# %%
students['names']
# Out:
# 'David'

# %%
students['name'] = 'Solomon'

# %%
students
# Out:
# {'name': 'Solomon',
#  'age': 30,
#  'school': 'Gomycode',
#  'names': 'David',
#  'Oladimeji': 'namessss'}

# %%
type(students)
# Out:
# dict

# %%
# View the dictionary
gomycode
# Out:
# {'Olashile': 1000, 'Course3': 'Game Dev', 'Course4': 'Mobile', 'Course5': 'AI'}

# %%
# Check the data type
type(gomycode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-649448d3f571> in <cell line: 2>()
#       1 # Check the data type
# ----> 2 type(gomycode)
#
# NameError: name 'gomycode' is not defined

# %%
# Access specific element in the dictionary using a specific key (ex: Key2)
students[]
# Out:
# 21

# %%
'Here is my stuff'
"Here's my stuff"
# Out:
# Here's

# %%
# Define a dictionary for a bank client listing all his/her assets!
client_assets = {'Real estate': 150000.02,
                 "stocks": 10000,
                 "savings": 20000}

print(client_assets)
# Out:
# {'Real estate': 150000.02, 'stocks': 10000, 'savings': 20000}

# %%
# Access elements in the dictionary
client_assets['savings']
# Out:
# 20000

# %%
client_assets['Crypto'] = 1000000

# %%
client_assets
# Out:
# {'Real estate': 200000, 'stocks': 20000, 'Crypto': 1000000}

# %%
client_assets['stocks'] = 20000

# %%
del client_assets['savings']

# %%
# Add a new item to an existing dictionary
client_assets['Crypto'] = 5000000
print(client_assets)
# Out:
# {'Real estate': 15000000, 'stocks': 10000, 'savings': 20000, 'Gold': 2000000, 'Crypto': 5000000}

# %%
# remove an item from the dictionary
del client_assets['savings']

# %%
# add an item

client_assets['savings'] = 20000

# %%
client_assets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-4f9683d29bfd> in <cell line: 1>()
# ----> 1 client_assets
#
# NameError: name 'client_assets' is not defined

# %%
del client_assets

# %%
print(client_assets)
# Out:
# {'Real estate': 15000000, 'stocks': 10000, 'Gold': 34900000, 'savings': 20000}

# %%
# delete the entire dictionary
# Note that you cannot print it out again because the entire dictionary has been deleted
del client_assets

# %%
print(client_assets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-4af2ef9719f9> in <cell line: 1>()
# ----> 1 print(client_assets)
#
# NameError: name 'client_assets' is not defined

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Create a dictionary with 3 of your favourite stocks and their prices**

# %%
fav_stock = {'AMAZON' : 15000, 'AAPL' : 25000, 'BTC' : 100000}
fav_stock
# Out:
# {'AMAZON': 15000, 'AAPL': 25000, 'BTC': 100000}

# %% [markdown]
# # 4. STRINGS

# %%
# A string in Python is a sequence of characters
# String can be enclosed by either double or single quotes
course = 'Gomycode data science'
course
# Out:
# 'Gomycode data science'

# %%
x = 'my brother\'s friend'
x
# Out:
# "my brother's friend"

# %%
# Obtain the datatype
type(course)
# Out:
# str

# %%
# Combining two strings together (Let's combine the first and last name of a bank's client)
first_name = 'Femi'
last_name = 'Akinola'
full_name = first_name + last_name
full_name
# Out:
# 'FemiAkinola'

# %%
full_name = first_name + ' ' + last_name
full_name
# Out:
# 'Femi Akinola'

# %%
full_name.title()
# Out:
# 'Femi Akinola'

# %%
full_name = first_name + ' ' + last_name
full_name
# Out:
# 'Austin Akauba'

# %%
full_name.upper()
# Out:
# 'AUSTIN AKAUBA'

# %%
full_name.lower()
# Out:
# 'austin akauba'

# %%
institute = 'Gomycode'
institute
# Out:
# 'Gomycode'

# %%
type(institute)
# Out:
# str

# %%
new_institute = institute.split()

# %%
type(new_institute)
# Out:
# list

# %%
email = 'Joshua Olamide'

# %%
email.split(' ')
# Out:
# ['Joshua', 'Olamide']

# %%
school.split()
# Out:
# ['This', 'is', 'my', 'school']

# %%
email_address = 'ekene.joachim@gmail.com'

# %%
# Splitting with a delimiter
email_address.split('.')
# Out:
# ['ekene', 'joachim@gmail', 'com']

# %%
# You can combine both strings together and add spaces in between
full_name = first_name + " " + last_name
full_name
# Out:
# 'Laila Aly'

# %%
gomycode = 'This is a data science class'

# %%
type(gomycode)
# Out:
# str

# %%
# Methods on strings
# upper will be used to convert the string into upper case
gomycode = gomycode.upper()

# %%
# Split us used to divide up the string into words
# The output from split is a list
x = gomycode.split()
x
# Out:
# ['THIS', 'IS', 'A', 'DATA', 'SCIENCE', 'CLASS']

# %%
# Let's check that the datatype is list!
type(x)
# Out:
# list

# %%
# you can index any element in the list using indexing
x[4]
# Out:
# 'SCIENCE'

# %%
x = y.split('.')

# %%
# you can specify which letter could be choosed to perform the split
my_string = 'laila.aly@gmail.com'
z = my_string.split('@')
z
# Out:
# ['laila.aly', 'gmail.com']

# %%
feedback = input('Please provide a feedback on our services ')
print(feedback.split())
# Out:
# Please provide a feedback on our services Wonderful experience
# ['Wonderful', 'experience']

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Write a code that takes an input from a bank client asking him/her about their feedback regarding the service. The code should split the client input into words and print them on screen**

# %%
y = input('Guy how far')
print(y.split())
# Out:
# Guy how farI dey alright
# ['I', 'dey', 'alright']

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **Write a code that prompts a user requesting his/her e-mail and then extracts the user first name (Note that the e-mail is in firstname.lastname@gmail.com**

# %%
email = input('What is your email address ')
email1 = email.split('.')
print(email1[0])
# Out:
# What is your email address lagbaja.ade@gmail.com
# lagbaja

# %%
email = input('What is your email address: ')
# Out:
# What is your email address: firstname.lastname@gmail.com

# %%
email1 = email.split('.')
email1
# Out:
# ['firstname', 'lastname@gmail', 'com']

# %%
email1[0]
# Out:
# 'firstname'

# %%
email2 = email1[0].split('.')
email2
# Out:
# ['firstname', 'lastname']

# %%
email2[0]
# Out:
# 'firstname'

# %%
email = input('What is your email address ')
email1 = email.split('@')
email2 = email1[0].split('.')
email2[0]
# Out:
# What is your email address samuel.femi@gmail.com
# 'samuel'

# %%
email1[0]
# Out:
# 'samuel.femi'

# %%
email2
# Out:
# ['samuel', 'femi']

# %%
# Out:
# 'samuel'

# %% [markdown]
# # 5. TUPLES

# %%
# A tuple is a sequence of immutable Python objects.
# Tuples are sequences, just like lists.
# The differences between tuples and lists are, the tuples cannot be changed unlike lists and tuples use parentheses, whereas lists use square brackets.

# %%
name = ('Amaka', 'Feranmi', 2, 6, 6)
name
# Out:
# ('Amaka', 'Feranmi', 2, 6, 6)

# %%
name[1] = 'Oladimeji'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-ed59a9015b4f> in <cell line: 1>()
# ----> 1 name[1] = 'Oladimeji'
#
# TypeError: 'tuple' object does not support item assignment

# %%
type(name)
# Out:
# tuple

# %%
name_list = ['Amaka', 'Feranmi', 2, 6, 6]
name_list
# Out:
# ['Amaka', 'Feranmi', 2, 6, 6]

# %%
name_list[1] = 'Oladimeji'
print(name_list)
# Out:
# ['Amaka', 'Oladimeji', 2, 6, 6]

# %%
list_1 = ['gomycode', 20, 10, 1]
list_1
# Out:
# ['gomycode', 20, 10, 1]

# %%
list_1[0] = 'Ekene'
list_1
# Out:
# ['Ekene', 20, 10, 1]

# %%
tuple_1 = ('gomycode', 20, 10, 1)
tuple_1
# Out:
# ('gomycode', 20, 10, 1)

# %%
tuple_2 = ('datascience', 2, 3, 1)
tuple_2
# Out:
# ('datascience', 2, 3, 1)

# %%
class1 = ('Uzi', 'David', 56)
class2 = ('Shayo', 'John', 78, 56)

# %%
class1.add('Sam')
class1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-28bada88c68c> in <cell line: 1>()
# ----> 1 class1.add('Sam')
#       2 class1
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
new_class = class1 + class2
new_class
# Out:
# ('Uzi', 'David', 56, 'Shayo', 'John', 78, 56)

# %%
new_class[7] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-20bb8af41117> in <cell line: 1>()
# ----> 1 new_class[7] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
new_classs = 'Uzi'

len(new_classs)
# Out:
# 3

# %%
len(new_class)
# Out:
# 7

# %%
class1[0] + ' ' + class2[0]
# Out:
# 'Uzi Shayo'

# %%
new_class[-5:-2]
# Out:
# (56, 'Shayo', 'John')

# %%
new_tuple = tuple_1 + tuple_2
new_tuple
# Out:
# ('gomycode', 20, 10, 1, 'datascience', 2, 3, 1)

# %%
old_tuple = tuple_2 + tuple_1
old_tuple
# Out:
# ('datascience', 2, 3, 1, 'gomycode', 20, 10, 1)

# %%
tuple_1[1:4]
# Out:
# (20, 10, 1)

# %%
tuple_1
# Out:
# ('gomycode', 20, 10, 1)

# %%
type(tuple_1)
# Out:
# tuple

# %%
tuple_1[-1:-4]
# Out:
# ()

# %%
tuple_1[2] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-3c330a9adcb8> in <cell line: 1>()
# ----> 1 tuple_1[2] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple_2 = ('Ebele', 20, 40, 'Demola', 100)
tuple_2
# Out:
# ('Ebele', 20, 40, 'Demola', 100)

# %%
new_tuple = tuple_2 + tuple_1
new_tuple
# Out:
# ('Ebele', 20, 40, 'Demola', 100, 'Gomycode', 10, 20, 'Jide', 100, 40)

# %%
tuple_1
# Out:
# ['Gomycode', 10, 10]

# %%
# Accessing elements in a tuple
tuple_1[1]
# Out:
# 'APPL'

# %%
# Tuple slicing
tuple_1
# Out:
# ('APPL', 10)

# %%
# Changing a value of a tuple does not work!
# 'tuple' object does not support item assignment
tuple_1[1] = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-0d93d25c1b58> in <module>()
#       1 # Changing a vlue of a tuple does not work!
#       2 # 'tuple' object does not support item assignment
# ----> 3 tuple_1[1] = 0
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Create a New Tuple from existing Tuples
tuple_3 = tuple_1 + tuple_2
tuple_3
# Out:
# ('GOOG', 'APPL', 10, 15, 1992, 450, 55, 977, 2100)

# %% [markdown]
# **MINI CHALLENGE #7:**
# - **Define a tuple with your first name, last name, age and the number of stocks in your portfolio. Find the length and type as well.**

# %%
details = ('Ade', 'Dami', 33, 10)
print(len(details))
print(type(details))
# Out:
# 4
# <class 'tuple'>

# %%
information = ('Femi', 'Adedayo', 32, 20)
information
# Out:
# ('Femi', 'Adedayo', 32, 20)

# %%
type(information)
# Out:
# tuple

# %%
len(information)
# Out:
# 4

# %% [markdown]
# # 6. SETS

# %%
# A set is an unordered collection of items. Every element is unique (no duplicates).
# A set is created by placing all the items (elements) inside curly braces {}, separated by comma or by using the built-in function set().
# set of integers
Data_science = {'Olakunle', 'Sapphire', 67, 78}
Data_science
# Out:
# {67, 78, 'Olakunle', 'Sapphire'}

# %%
Data_science.add('David')

# %%
Data_science.remove(67)

# %%
del Data_science

# %%
Data_science
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-eb74fc2b260b> in <cell line: 1>()
# ----> 1 Data_science
#
# NameError: name 'Data_science' is not defined

# %%
# set do not have duplicates
my_set = {'Data Science', 'ML', 'AI', 'AI', 'Game Dev'}
print(my_set)
# Out:
# {'AI', 'Data Science', 'Game Dev', 'ML'}

# %%
# Out:
# {5, 6, 'AAPL', 'APPL', 'GOOG', 'T', 'TSLA'}

# %% [markdown]
# **MINI CHALLENGE #8:**
# - **Remove the duplicates from the following list:**
#
#
# ```
# my_list = ['GOOG', 'APPL', 'T','TSLA','T','AAPL', 5, 6,5]
# ```

# %%
my_list = ['GOOG', 'AAPL', 'T','TSLA','T','AAPL', 5, 6,5]
my_list
# Out:
# ['GOOG', 'AAPL', 'T', 'TSLA', 'T', 'AAPL', 5, 6, 5]

# %%
set(my_list)
# Out:
# {5, 6, 'AAPL', 'GOOG', 'T', 'TSLA'}

# %%
my_list =
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-a48bfc5811fe> in <cell line: 1>()
# ----> 1 my_list.set()
#
# AttributeError: 'tuple' object has no attribute 'set'

# %% [markdown]
# # MINI CHALLENGE SOLUTIONS

# %% [markdown]
# **MINI CHALLENGE #1 SOLUTION:**
# - **What will this code generate?**
# ```
# stock_1_price = 20
# stock_2_price = 30
# print((stock_1_price < stock_2_price))
# print(stock_1_price == stock_2_price)
# ```

# %%
stock_1_price = 20
stock_2_price = 30
print((stock_1_price < stock_2_price))
print(stock_1_price == stock_2_price)
# Out:
# True
# False

# %% [markdown]
# **MINI CHALLENGE #2 SOLUTION:**
# - **Print the first, second and last element in the list**
# - **Print all elements in the list, first 3 elements, and last three elements**
#
# ```
# stocks = ["GOOG", "TSLA", "AAPL", "T", "SP500", "BTC", "EUR/USD"]
# ```

# %%
stocks = ["GOOG", "TSLA", "AAPL", "T", "SP500", "BTC", "EUR/USD"]
print(stocks[0])
print(stocks[1])
print(stocks[-1])
# Out:
# GOOG
# TSLA
# EUR/USD

# %%
print(stocks[:])
print(stocks[0:3])
print(stocks[4:])
# Out:
# ['GOOG', 'TSLA', 'AAPL', 'T', 'SP500', 'BTC', 'EUR/USD']
# ['GOOG', 'TSLA', 'AAPL']
# ['SP500', 'BTC', 'EUR/USD']

# %% [markdown]
# **MINI CHALLENGE #3 SOLUTION:**
# - **Print GOOG**
# - **Print AAPL, GOOG, TSLA**
# - **Print T with two different ways**
#
# ```
# my_list = ["SP500", ["AAPL", "GOOG", "TSLA"], "BTC", "T"]
# ```

# %%
my_list = ["SP500", ["AAPL", "GOOG", "TSLA"], "BTC", "T"]

# %%
print(my_list[1][1])
# Out:
# GOOG

# %%
print(my_list[1])
# Out:
# ['AAPL', 'GOOG', 'TSLA']

# %%
print(my_list[3])
# Out:
# T

# %%
print(my_list[-1])
# Out:
# T

# %% [markdown]
# **MINI CHALLENGE #4 SOLUTION:**
# - **Create a dictionary with 3 of your favourite stocks and their prices**

# %%
stocks = {"SP500": 3000,
          "AAPL": 400,
          "TSLA": 2200}
print(stocks)
# Out:
# {'SP500': 3000, 'AAPL': 400, 'TSLA': 2200}

# %% [markdown]
# **MINI CHALLENGE #5 SOLUTION:**
# - **Write a code that takes an input from a bank client asking him/her about their feedback regarding the service. The code should split the client input into words and print them on screen**

# %%
my_string = str(input("What did we do at the bank today? are you satisfied with the service"))
words = my_string.split(" ")
print("Here are the list of words you entered:", words)
# Out:
# What did we do at the bank today? are you satisfied with the serviceMy experience today was positive, the service is perfect! great job everyone
# Here are the list of words you entered: ['My', 'experience', 'today', 'was', 'positive,', 'the', 'service', 'is', 'perfect!', 'great', 'job', 'everyone']

# %% [markdown]
# **MINI CHALLENGE #6 SOLUTION:**
# - **Write a code that prompts a user requesting his/her e-mail and then extracts the user first name (Note that the e-mail is in firstname.lastname@gmail.com**

# %%
input_str = input("Welcome to the bank, please enter your e-mail address:")
out_str = input_str.split('@')
out_str = out_str[0].split('.')
print(out_str[0])
# Out:
# Enter your e-mail address:ryan.ahmed@yahoo.com
# ryan

# %% [markdown]
# **MINI CHALLENGE #7 SOLUTION:**
# - **Define a tuple with your first name, last name, age and the number of stocks in your portfolio. Find the length and type as well.**

# %%
my_tuple = ("Ryan", "ahmed", 25, 10)
print(my_tuple)
# Out:
# ('Ryan', 'ahmed', 25, 10)

# %%
len(my_tuple)
# Out:
# 4

# %%
type(my_tuple)
# Out:
# tuple

# %% [markdown]
# **MINI CHALLENGE #8 SOLUTION:**
# - **Remove the duplicates from the following list:**
#
#
# ```
# my_list = ['GOOG', 'APPL', 'T','TSLA','T','AAPL', 5, 6,5]
# ```

# %%
my_list = ['GOOG', 'APPL', 'T','TSLA','T','AAPL', 5, 6, 5]
out_list = list(set(my_list))
print(out_list)
# Out:
# [5, 6, 'T', 'APPL', 'GOOG', 'TSLA', 'AAPL']
