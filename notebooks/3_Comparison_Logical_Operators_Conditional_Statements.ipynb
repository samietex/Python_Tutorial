# %% [markdown]
# # 1. COMPARISON OPERATORS

# %%
# Comparison Operator output could be "True" or "False"
# Let's cover equal '==' comparison operator first
# It's simply a question: "Is stock_1_price equals stock_2_price or not?"
# "True" output means condition is satisfied
# "False" output means Condition is not satisfied (condition is not true)

stock_1_price = 10000
stock_2_price = 1000
stock_1_price >= stock_2_price
# Out:
# True

# %% [markdown]
# == (Comparison)
# = (Assignment)

# %%
# Greater than or equal operator '>='

stock_1_price = 2000
stock_2_price = 1000
stock_1_price >= stock_2_price
# Out:
# True

# %%
# Note that '==' is a comparison operator
# Note that '=' is used for variable assignment (put 10 in stock_1_price)
stock_1_price = 10

# %%
stock_1_price
# Out:
# 10

# %%
# Comparison operators work with strings as well
'Finance' == 'Finance'
# Out:
# True

# %%
# Both strings have to exactly match (lower case vs. upper case)
'finance' == 'finance'
# Out:
# True

# %%
# Not equal comparison operator '!='

stock_1_price = 1000
stock_2_price = 1000
stock_1_price != stock_2_price
# Out:
# False

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **Without executing the code cell, What will this code generate?**
#
# ```
# stock_1_price = 15
# stock_2_price = 10
#
# print(stock_1_price == stock_2_price)
# print(stock_1_price != stock_2_price)
# print(stock_1_price > stock_2_price)
# print(stock_1_price < stock_2_price)
# ```

# %%
stock_1_price = 15
stock_2_price = 10

print(stock_1_price == stock_2_price)
print(stock_1_price != stock_2_price)
print(stock_1_price > stock_2_price)
print(stock_1_price < stock_2_price)
# Out:
# False
# True
# True
# False

# %% [markdown]
# # 2. LOGICAL OPERATORS

# %%
# For "and" logical operators, both arguments must be "True" in order for the output to be "True"
# (Note that this is the only case in which the 'and' logical operator generates a True output)
# 1 and 1 = 1
True and True
# Out:
# True

# %%
# 0 and 1 = 0
False and True
# Out:
# False

# %%
True and False
# Out:
# False

# %%
# 0 and 0 = 0
False and False
# Out:
# False

# %%
# For "or" logical operators, if any one of the arguments is "True", the output will be "True"
# 1 or 1 = 1
True or True
# Out:
# True

# %%
# 1 or 0 = 1
True or False
# Out:
# True

# %%
# 0 or 1 = 1
False or True
# Out:
# True

# %%
# 0 or 0 = 0 (Note that this is the only case in which the 'or' logical operator generates a False output)
False or False
# Out:
# False

# %%
benedict = 10
austin = 15
denis = 20
tomisin = 15

(benedict > austin) or (tomisin > denis)
# Out:
# False

# %%
benedict > austin
# Out:
# False

# %%
tomisin > denis
# Out:
# True

# %%
False or True
# Out:
# True

# %%
jide = 20
adams = 30
demola = 40
michael = 20

(jide == michael) and (adams < demola)
# Out:
# True

# %%
 # True and False = False
(10>3) or (9==3)
# Out:
# True

# %%
# True or False = True
(9>3) or (12==10)
# Out:
# True

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Without executing the code cell, What will these two lines of code generate?**
#
# ```
# print('FINANCE'!='FINANCE' and (10 > 3) and (20 == 20))
# ```
#
# ```
# print('Finance'!='FINANCE' or (16 > 20) or (25 == 25))
# ```

# %%
print('FINANCE'!='FINANCE' and (10 > 3) and (20 == 20))
# Out:
# False

# %%
print('Finance'!='FINANCE' or (16 > 20) or (25 == 25))
# Out:
# True

# %%
True or False
# Out:
# True

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Without executing the code cell, What will these two lines of code generate?**
#
# ```
# a = 5
# b = 3.5
#
# print(a == b or a != b)
# print(a == b and a != b)
# ```

# %% [markdown]
# # 3. CONDITIONAL STATEMENTS

# %% [markdown]
# - A simple if-else statement is written in Python as follows:
#
# ```
# if condition:
#   statement #1
# else:
#   statement #2
# ```
#
# - If the condition is true, execute the first indented statement
# - if the condition is not true, then execute the else indented statements.
# - Note that Python uses indentation (whitespace) to indicate code sections and scope.

# %%
name = input('What is your name ').capitalize()

if name == 'John':
  print('Welcome, John')
else:
  print('Stranger')
# Out:
# What is your name john
# Welcome, John

# %%
if input('What is your name: ') == 'Austin':
  print('This is Austin')
else:
  print('This is a stranger')
# Out:
# What is your name: Austin
# This is Austin

# %%
name = input('What is your name ')

if name == 'Tomm':
  print('Welcome, Tomm')
elif input('What is your best meal ') == 'Pounded yam':
  print(f'Excellent. Your name is {name}')
else:
  print(f'You are not welcome, {name}. ')
# Out:
# What is your name Tomm
# Welcome, Tomm

# %%
name = input('What is your name? ')
if name == 'Tomisin':
  print('Welcome, Tomisin')
elif input(f"Hi {name}. What is Tomisin's favorite weekday? ") == 'Friday' :   # elif means else if statement
  print('You are welcome')
else:
  print('Access denied!!!', name)
# Out:
# What is your name? Tomisin
# Welcome, Tomisin

# %%
if 10 > 9:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
if 5 == 10:
    print('If condition is True')
else:
    print('If condition is False')
# Out:
# If condition is False

# %%
if 5 == 7:
    print('First statement is true')
elif 2 == 4:
    print('Second statement is true')
else:
    print('Last statement is true')
# Out:
# Last statement is true

# %%
if 5 < 7:
    print('First statement is true')
elif 2 > 4:
    print('Second statement is true')
else:
    print('Last statement is true')
# Out:
# First statement is true

# %%
# Let's take an input from the user and grant or deny access accordingly
name = input('Enter your username:')

if name == 'Ryan':
    print("Access granted")
else:
    print("Access Denied")
# Out:
# Enter your username:Ryan
# Access granted

# %%
# Let's make the code more robust (case insensitive)
name = input('Enter your username:')

if name == 'Ryan' or name =='RYAN' or name =='ryan':
    print("Access granted")
else:
    print("Access Denied")
# Out:
# Enter your username:RYAN
# Access granted

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Write a code that takes a number from the user and indicates if it's positive or negative**

# %%
number = int(input('Provide a number '))

if number >= 0:
  print('This is a positive number')
else:
  print('This is a negative number')
# Out:
# Provide a number 9
# This is a positive number

# %%
number = input('Input a value: ')
number = int(number)
if number >= 0:
  print('This is a positive value')
else:
  print('This is a negative value')
# Out:
# Input a value: -2
# This is a negative value

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Write a code that takes a number from the user and checks if the number is divisible by 3 but is not a multiple of 7**

# %%
number = int(input('Provide a number '))
if number % 3 == 0 and number % 7 != 0:
  print(f'The number, {number} is divisible by 3 and not a multiple of 7')
else:
  print(f'The number, {number} does not fulfill the conditions')
# Out:
# Provide a number 6
# The number, 6 is divisible by 3 and not a multiple of 7

# %%
number = int(input('Input a value: '))
if number % 3 == 0 and number % 7 != 0:
  print('The value you inputed is divisible by 3, but not a multiple of 7')
else:
  print('The value you inputed does not fulfill the conditions')
# Out:
# Input a value: 21
# The value you inputed does not fulfill the conditions

# %%
import math

x = 60 # in radians

x = ((3.14/180) * x)

math.cos(x)
# Out:
# 0.5004596890082056

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **Write a code that takes a number from the user and indicate if the number is even or odd**

# %%
number = int(input('Provide a number '))

if number % 2 == 0:
  print(f'The number, {number} is an even number.')
else:
  print(f'The number, {number} is an odd number.')
# Out:
# Provide a number 8
# The number, 8 is an even number.

# %%
number = int(input('Provide an imaginary number: '))

if number % 2 == 0:
  print('This is an even number')
else:
  print('This is an odd number')
# Out:
# Provide an imaginary number: 1
# This is an odd number

# %% [markdown]
# # MINI CHALLENGE SOLUTIONS

# %% [markdown]
# **MINI CHALLENGE #1 SOLUTION:**
# - **Without executing the code cell, What will this code generate?**
#
# ```
# stock_1_price = 15
# stock_2_price = 10
#
# print(stock_1_price == stock_2_price)
# print(stock_1_price != stock_2_price)
# print(stock_1_price > stock_2_price)
# print(stock_1_price < stock_2_price)
# ```

# %%
stock_1_price = 15
stock_2_price = 10

print(stock_1_price == stock_2_price)
print(stock_1_price != stock_2_price)
print(stock_1_price > stock_2_price)
print(stock_1_price < stock_2_price)
# Out:
# False
# True
# True
# False

# %% [markdown]
# **MINI CHALLENGE #2 SOLUTION:**
# - **Without executing the code cell, What will these two lines of code generate?**
#
# ```
# print( 'Finance'!='FINANCE' and (10 > 3) and (20 == 20))
# ```
#
# ```
# print( 'Finance'!='FINANCE' or (16 > 20) or (25 == 25))
# ```

# %%
# FALSE and TRUE and TRUE
print('FINANCE'!='FINANCE' and (10 > 3) and (20 == 20))
# Out:
# False

# %%
# TRUE or FALSE or TRUE
print('Finance'!='FINANCE' or (16 > 20) or (25 == 25))
# Out:
# True

# %% [markdown]
# **MINI CHALLENGE #3 SOLUTION:**
# - **Without executing the code cell, What will these two lines of code generate?**
#
# ```
# a = 5
# b = 3.5
#
# print(a == b or a != b)
# print(a == b and a != b)
# ```

# %%
a = 5
b = 3.5

print(a == b or a != b) # False or True = True
print(a == b and a != b) # False and True = False
# Out:
# True
# False

# %% [markdown]
# **MINI CHALLENGE #4 SOLUTION:**
# - **Write a code that takes a number from the user and indicates if it's positive or negative or zero**

# %%
x = int(input("Please enter an integer: "))

if x < 0:
    print('Number is Negative')
elif x > 0:
    print('Number is Positive')
else:
    print ('Number is zero')
# Out:
# Please enter an integer: 9
# Number is Positive

# %% [markdown]
# **MINI CHALLENGE #5 SOLUTION:**
# - **Write a code that takes a number from the user and checks if the number is divisible by 3 but is not a multiple of 7**

# %%
# Try 21

i = int(input("Enter a number between 1 and 100:"))

if (i % 3 == 0) and (i % 7 !=0):
    print("Number satisfies the requirement; The number is divisible by 3 and not multiple of 7")
else:
    print("The number does not satisfy the requirements")
# Out:
# Enter a number between 1 and 100:21
# The number does not satisfy the requirements

# %% [markdown]
# **MINI CHALLENGE #6 SOLUTION:**
# - **Write a code that takes a number from the user and indicate if the number is even or odd**

# %%
x = int(input("Please enter an integer from 1 to 1000: "))

if x % 2==0:
    print('Number is Even')
else:
    print('Number is odd')
# Out:
# Please enter an integer from 1 to 1000: 50
# Number is Even

# %%
monthly_income = [1000, 2000, 5000, 500, 600, 5000, 3000]

# %%
monthly_income[1]
# Out:
# 2000

# %%
data = []

# %%
data
# Out:
# []

# %%
data = [20, 'Olamide', 'Uzi', 50, 'Gomycode']

# %%
data[2:4]
# Out:
# ['Uzi', 50]

# %%
python = {'name' : 'Solomon', 'height' : '184 cm', 'weight' : '75 kg', 'status' : 'married'}
python
# Out:
# {'name': 'Solomon', 'height': '184 cm', 'weight': '75 kg', 'status': 'married'}

# %%
type(python)
# Out:
# dict

# %%
python.items()
# Out:
# dict_items([('name', 'Solomon'), ('height', '184 cm'), ('weight', '75 kg'), ('status', 'married')])

# %%
programming = {20, 58, 'David', 'Shola', 78}

# %%
programming[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9df39e7f338c> in <cell line: 1>()
# ----> 1 programming[1]
#
# TypeError: 'set' object is not subscriptable

# %%
programming.add(23)

# %%
programming
# Out:
# {20, 23, 58, 78, 'David', 'Shola'}

# %%
programming.remove('Shola')

# %%
programming
# Out:
# {20, 23, 58, 78, 'David'}

# %%
del programming

# %%
programming
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e572f76fb33f> in <cell line: 1>()
# ----> 1 programming
#
# NameError: name 'programming' is not defined

# %%
friends = ('Femi', 'Ada', 'Cynthia', 'David', 'Majeed')
friends
# Out:
# ('Femi', 'Ada', 'Cynthia', 'David', 'Majeed')

# %%
friends[1] = 'Dami'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-039ab59ffff4> in <cell line: 1>()
# ----> 1 friends[1] = 'Dami'
#
# TypeError: 'tuple' object does not support item assignment

# %%
import random

random.randint(1, 20)
# Out:
# 20
